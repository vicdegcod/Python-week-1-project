# %% [markdown]
# 2.2: TryOut

# %% [markdown]
# 1

# %% [markdown]
# 2.

# %%
def largest():
    l1 = [43, 89, 67, 56, 12]
    print(max(l1))

largest()
# Out:
# 89

# %% [markdown]
# 3

# %%
def sum_all():
    list1 = [10, 20, 30, 40, 50]
    for num in list1:
        total += num
        print(total)

sum_all()
# Out:
# 10
# 30
# 60
# 100
# 150

# %% [markdown]
# 4

# %%
list2 = [23, 45, 67, -10, 23, 50, -10]
